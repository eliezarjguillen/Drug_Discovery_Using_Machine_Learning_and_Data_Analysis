# %% [markdown]
# # **Computational Drug Discovery - Download Bioactivity Data**
#
# Followed tutorial by Chanin Nantasenamat
#
# > Indented block

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.4)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jsonschema 4.19.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for protein of interest**
#
# ---

# %%
# Target search for Tropin
target = new_client.target
target_query = target.search('Troponin cardiac muscle')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references           organism  \
# 0                                                   []       Homo sapiens
# 1                                                   []       Homo sapiens
# 2                                                   []       Homo sapiens
# 3    [{'xref_id': 'Q9ERN6', 'xref_name': None, 'xre...       Mus musculus
# 4    [{'xref_id': 'B0LPN4', 'xref_name': None, 'xre...  Rattus norvegicus
# ..                                                 ...                ...
# 173                                                 []       Homo sapiens
# 174                                                 []       Homo sapiens
# 175                                                 []       Homo sapiens
# 176                                                 []       Homo sapiens
# 177                                                 []       Homo sapiens
#
#                                      pref_name  score  species_group_flag  \
# 0                     Troponin, cardiac muscle   48.0               False
# 1               Fast skeletal troponin complex   34.0               False
# 2       Serine/threonine-protein kinase TNNI3K   27.0               False
# 3                         Ryanodine receptor 2   23.0               False
# 4                         Ryanodine receptor 2   23.0               False
# ..                                         ...    ...                 ...
# 173  Phosphodiesterase 4 and 5 (PDE4 and PDE5)    2.0               False
# 174              Voltage-gated calcium channel    2.0               False
# 175            Phosphodiesterases; PDE5 & PDE6    1.0               False
# 176            Voltage-gated potassium channel    0.0               False
# 177             3',5'-cyclic phosphodiesterase    0.0               False
#
#     target_chembl_id                                  target_components  \
# 0      CHEMBL2095202  [{'accession': 'P63316', 'component_descriptio...
# 1      CHEMBL3831282  [{'accession': 'P48788', 'component_descriptio...
# 2         CHEMBL5260  [{'accession': 'Q59H18', 'component_descriptio...
# 3         CHEMBL4745  [{'accession': 'E9Q401', 'component_descriptio...
# 4         CHEMBL3388  [{'accession': 'B0LPN4', 'component_descriptio...
# ..               ...                                                ...
# 173    CHEMBL2111340  [{'accession': 'O76074', 'component_descriptio...
# 174    CHEMBL2363032  [{'accession': 'O95180', 'component_descriptio...
# 175    CHEMBL2095220  [{'accession': 'O76074', 'component_descriptio...
# 176    CHEMBL2362996  [{'accession': 'P51787', 'component_descriptio...
# 177    CHEMBL2363066  [{'accession': 'O76074', 'component_descriptio...
#
#                target_type   tax_id
# 0          PROTEIN COMPLEX   9606.0
# 1          PROTEIN COMPLEX   9606.0
# 2           SINGLE PROTEIN   9606.0
# 3           SINGLE PROTEIN  10090.0
# 4           SINGLE PROTEIN  10116.0
# ..                     ...      ...
# 173      SELECTIVITY GROUP   9606.0
# 174  PROTEIN COMPLEX GROUP   9606.0
# 175      SELECTIVITY GROUP   9606.0
# 176         PROTEIN FAMILY   9606.0
# 177         PROTEIN FAMILY   9606.0
#
# [178 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for protein of choice, single protein preferred**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2095202'

# %% [markdown]
# Here, we will retrieve only bioactivity data for target protein that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None           Active      5651917                  []
# 1         None         inactive      5651918                  []
# 2         None         inactive      5651919                  []
# 3         None         inactive      5651920                  []
# 4         None           Active      5651921                  []
# 5         None           Active      5651922                  []
# 6         None           Active      5651923                  []
# 7         None           Active      5651924                  []
# 8         None           Active      5651925                  []
# 9         None           Active      5651926                  []
# 10        None         inactive      5651927                  []
# 11        None         inactive      5651928                  []
# 12        None         inactive      5651929                  []
# 13        None         inactive      5651930                  []
# 14        None           Active      5651931                  []
# 15        None         inactive      5651932                  []
# 16        None         inactive      5651933                  []
# 17        None         inactive      5651934                  []
# 18        None           Active      5651935                  []
# 19        None         inactive      5651936                  []
# 20        None           Active      5651937                  []
# 21        None         inactive      5651938                  []
# 22        None         inactive      5651939                  []
# 23        None         inactive      5651940                  []
# 24        None         inactive      5651941                  []
# 25        None           Active      5651942                  []
# 26        None         inactive      5651943                  []
# 27        None         inactive      5651944                  []
# 28        None           Active      5651945                  []
# 29        None           Active      5651946                  []
# 30        None           Active      5651947                  []
# 31        None         inactive      5651948                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 1    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 2    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 3    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 4    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 5    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 6    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 7    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 8    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 9    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 10   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 11   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 12   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 13   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 14   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 15   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 16   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 17   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 18   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 19   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 20   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 21   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 22   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 23   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 24   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 25   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 26   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 27   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 28   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 29   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 30   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 31   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
# 18          B                    None                   None  BAO_0000190
# 19          B                    None                   None  BAO_0000190
# 20          B                    None                   None  BAO_0000190
# 21          B                    None                   None  BAO_0000190
# 22          B                    None                   None  BAO_0000190
# 23          B                    None                   None  BAO_0000190
# 24          B                    None                   None  BAO_0000190
# 25          B                    None                   None  BAO_0000190
# 26          B                    None                   None  BAO_0000190
# 27          B                    None                   None  BAO_0000190
# 28          B                    None                   None  BAO_0000190
# 29          B                    None                   None  BAO_0000190
# 30          B                    None                   None  BAO_0000190
# 31          B                    None                   None  BAO_0000190
#
#     ... target_organism          target_pref_name target_tax_id text_value  \
# 0   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 1   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 2   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 3   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 4   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 5   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 6   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 7   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 8   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 9   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 10  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 11  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 12  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 13  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 14  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 15  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 16  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 17  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 18  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 19  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 20  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 21  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 22  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 23  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 24  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 25  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 26  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 27  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 28  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 29  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 30  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 31  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
#
#     toid  type units    uo_units upper_value    value
# 0   None  IC50    uM  UO_0000065        None  0.67676
# 1   None  IC50    uM  UO_0000065        None   71.472
# 2   None  IC50    uM  UO_0000065        None   71.481
# 3   None  IC50    uM  UO_0000065        None   12.683
# 4   None  IC50    uM  UO_0000065        None    2.724
# 5   None  IC50    uM  UO_0000065        None    1.819
# 6   None  IC50    uM  UO_0000065        None  0.55814
# 7   None  IC50    uM  UO_0000065        None    7.597
# 8   None  IC50    uM  UO_0000065        None    3.191
# 9   None  IC50    uM  UO_0000065        None    2.648
# 10  None  IC50    uM  UO_0000065        None    14.96
# 11  None  IC50    uM  UO_0000065        None   71.469
# 12  None  IC50    uM  UO_0000065        None   27.657
# 13  None  IC50    uM  UO_0000065        None   20.888
# 14  None  IC50    uM  UO_0000065        None    3.615
# 15  None  IC50    uM  UO_0000065        None   23.833
# 16  None  IC50    uM  UO_0000065        None   16.579
# 17  None  IC50    uM  UO_0000065        None   71.469
# 18  None  IC50    uM  UO_0000065        None    3.888
# 19  None  IC50    uM  UO_0000065        None   10.997
# 20  None  IC50    uM  UO_0000065        None     1.64
# 21  None  IC50    uM  UO_0000065        None   71.457
# 22  None  IC50    uM  UO_0000065        None   19.681
# 23  None  IC50    uM  UO_0000065        None   71.485
# 24  None  IC50    uM  UO_0000065        None   22.446
# 25  None  IC50    uM  UO_0000065        None    8.598
# 26  None  IC50    uM  UO_0000065        None    47.48
# 27  None  IC50    uM  UO_0000065        None   40.212
# 28  None  IC50    uM  UO_0000065        None    7.659
# 29  None  IC50    uM  UO_0000065        None    2.647
# 30  None  IC50    uM  UO_0000065        None    3.446
# 31  None  IC50    uM  UO_0000065        None   71.485
#
# [32 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Troponin_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None           Active      5651917                  []
# 1         None         inactive      5651918                  []
# 2         None         inactive      5651919                  []
# 3         None         inactive      5651920                  []
# 4         None           Active      5651921                  []
# 5         None           Active      5651922                  []
# 6         None           Active      5651923                  []
# 7         None           Active      5651924                  []
# 8         None           Active      5651925                  []
# 9         None           Active      5651926                  []
# 10        None         inactive      5651927                  []
# 11        None         inactive      5651928                  []
# 12        None         inactive      5651929                  []
# 13        None         inactive      5651930                  []
# 14        None           Active      5651931                  []
# 15        None         inactive      5651932                  []
# 16        None         inactive      5651933                  []
# 17        None         inactive      5651934                  []
# 18        None           Active      5651935                  []
# 19        None         inactive      5651936                  []
# 20        None           Active      5651937                  []
# 21        None         inactive      5651938                  []
# 22        None         inactive      5651939                  []
# 23        None         inactive      5651940                  []
# 24        None         inactive      5651941                  []
# 25        None           Active      5651942                  []
# 26        None         inactive      5651943                  []
# 27        None         inactive      5651944                  []
# 28        None           Active      5651945                  []
# 29        None           Active      5651946                  []
# 30        None           Active      5651947                  []
# 31        None         inactive      5651948                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 1    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 2    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 3    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 4    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 5    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 6    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 7    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 8    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 9    CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 10   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 11   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 12   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 13   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 14   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 15   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 16   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 17   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 18   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 19   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 20   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 21   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 22   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 23   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 24   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 25   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 26   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 27   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 28   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 29   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 30   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
# 31   CHEMBL1738244  PUBCHEM_BIOASSAY: Fluorescence-based biochemic...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# 5           B                    None                   None  BAO_0000190
# 6           B                    None                   None  BAO_0000190
# 7           B                    None                   None  BAO_0000190
# 8           B                    None                   None  BAO_0000190
# 9           B                    None                   None  BAO_0000190
# 10          B                    None                   None  BAO_0000190
# 11          B                    None                   None  BAO_0000190
# 12          B                    None                   None  BAO_0000190
# 13          B                    None                   None  BAO_0000190
# 14          B                    None                   None  BAO_0000190
# 15          B                    None                   None  BAO_0000190
# 16          B                    None                   None  BAO_0000190
# 17          B                    None                   None  BAO_0000190
# 18          B                    None                   None  BAO_0000190
# 19          B                    None                   None  BAO_0000190
# 20          B                    None                   None  BAO_0000190
# 21          B                    None                   None  BAO_0000190
# 22          B                    None                   None  BAO_0000190
# 23          B                    None                   None  BAO_0000190
# 24          B                    None                   None  BAO_0000190
# 25          B                    None                   None  BAO_0000190
# 26          B                    None                   None  BAO_0000190
# 27          B                    None                   None  BAO_0000190
# 28          B                    None                   None  BAO_0000190
# 29          B                    None                   None  BAO_0000190
# 30          B                    None                   None  BAO_0000190
# 31          B                    None                   None  BAO_0000190
#
#     ... target_organism          target_pref_name target_tax_id text_value  \
# 0   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 1   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 2   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 3   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 4   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 5   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 6   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 7   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 8   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 9   ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 10  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 11  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 12  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 13  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 14  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 15  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 16  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 17  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 18  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 19  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 20  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 21  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 22  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 23  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 24  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 25  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 26  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 27  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 28  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 29  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 30  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
# 31  ...    Homo sapiens  Troponin, cardiac muscle          9606       None
#
#     toid  type units    uo_units upper_value    value
# 0   None  IC50    uM  UO_0000065        None  0.67676
# 1   None  IC50    uM  UO_0000065        None   71.472
# 2   None  IC50    uM  UO_0000065        None   71.481
# 3   None  IC50    uM  UO_0000065        None   12.683
# 4   None  IC50    uM  UO_0000065        None    2.724
# 5   None  IC50    uM  UO_0000065        None    1.819
# 6   None  IC50    uM  UO_0000065        None  0.55814
# 7   None  IC50    uM  UO_0000065        None    7.597
# 8   None  IC50    uM  UO_0000065        None    3.191
# 9   None  IC50    uM  UO_0000065        None    2.648
# 10  None  IC50    uM  UO_0000065        None    14.96
# 11  None  IC50    uM  UO_0000065        None   71.469
# 12  None  IC50    uM  UO_0000065        None   27.657
# 13  None  IC50    uM  UO_0000065        None   20.888
# 14  None  IC50    uM  UO_0000065        None    3.615
# 15  None  IC50    uM  UO_0000065        None   23.833
# 16  None  IC50    uM  UO_0000065        None   16.579
# 17  None  IC50    uM  UO_0000065        None   71.469
# 18  None  IC50    uM  UO_0000065        None    3.888
# 19  None  IC50    uM  UO_0000065        None   10.997
# 20  None  IC50    uM  UO_0000065        None     1.64
# 21  None  IC50    uM  UO_0000065        None   71.457
# 22  None  IC50    uM  UO_0000065        None   19.681
# 23  None  IC50    uM  UO_0000065        None   71.485
# 24  None  IC50    uM  UO_0000065        None   22.446
# 25  None  IC50    uM  UO_0000065        None    8.598
# 26  None  IC50    uM  UO_0000065        None    47.48
# 27  None  IC50    uM  UO_0000065        None   40.212
# 28  None  IC50    uM  UO_0000065        None    7.659
# 29  None  IC50    uM  UO_0000065        None    2.647
# 30  None  IC50    uM  UO_0000065        None    3.446
# 31  None  IC50    uM  UO_0000065        None   71.485
#
# [32 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 4695

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  ... upper_value value
# 0                None        33969  ...        None  0.75
# 1                None        37563  ...        None   0.1
# 2                None        37565  ...        None  50.0
# 3                None        38902  ...        None   0.3
# 4                None        41170  ...        None   0.8
# ...               ...          ...  ...         ...   ...
# 7019             None     18798884  ...        None  2.44
# 7020             None     18798885  ...        None  2.54
# 7021             None     18798886  ...        None  3.81
# 7022             None     18798887  ...        None  3.46
# 7023             None     18798888  ...        None  2.78
#
# [4695 rows x 43 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id  ... standard_value
# 0          CHEMBL133897  ...          750.0
# 1          CHEMBL336398  ...          100.0
# 2          CHEMBL131588  ...        50000.0
# 3          CHEMBL130628  ...          300.0
# 4          CHEMBL130478  ...          800.0
# ...                 ...  ...            ...
# 7019      CHEMBL4293155  ...         2440.0
# 7020      CHEMBL4282558  ...         2540.0
# 7021      CHEMBL4281727  ...         3810.0
# 7022      CHEMBL4292349  ...         3460.0
# 7023      CHEMBL4278260  ...         2780.0
#
# [4695 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Troponin_cardiac_muscle_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Troponin_cardiac_muscle_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id  ...         class
# 0          CHEMBL133897  ...        active
# 1          CHEMBL336398  ...        active
# 2          CHEMBL131588  ...      inactive
# 3          CHEMBL130628  ...        active
# 4          CHEMBL130478  ...        active
# ...                 ...  ...           ...
# 4690      CHEMBL4293155  ...  intermediate
# 4691      CHEMBL4282558  ...  intermediate
# 4692      CHEMBL4281727  ...  intermediate
# 4693      CHEMBL4292349  ...  intermediate
# 4694      CHEMBL4278260  ...  intermediate
#
# [4695 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Troponin_03_bioactivity_data_curated.csv', index=False)

# %%
! zip Troponin.zip *.csv

# %%
! ls -l

# %% [markdown]
# ---
